# %% [markdown]
# <a href="https://colab.research.google.com/github/AbeerProg/AbeerPhd/blob/main/Gunning_Fog_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
# !pip install textstat
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import textstat

# %%
from google.colab import files
# Upload the Excel file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a501e8a-4c10-434c-a805-20ac1ffcf796" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a501e8a-4c10-434c-a805-20ac1ffcf796">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('/content/textonly.xlsx')

# %%
def calculate_fog_index(text):
    try:
        return textstat.gunning_fog(text)
    except Exception as e:
        print(f"Error calculating FOG index: {e}")
        return None

# 'text' column
df['Gunning_Fog_Index'] = df['text'].apply(calculate_fog_index)

# %%
# Display the results
print(df[['text', 'Gunning_Fog_Index']])

# Save the DataFrame with results to a new Excel file
df.to_excel('result_file.xlsx', index=False)
# Out:
#                                                    text  Gunning_Fog_Index
# 0     Some of the best food I've ever had! We were r...               5.82
# 1     Loved it the food was great. Can’t wait to go ...               2.20
# 2     Amazing food and staff was great! Can’t wait t...               2.20
# 3     This place is the sleeper hit of Wise County. ...               6.67
# 4                                    Food was wonderful               1.20
# ...                                                 ...                ...
# 9066                               Best burgers around!               1.20
# 9067                                            Awesome               0.40
# 9068       Great place to eat friendly and great people               3.20
# 9069                                   Amazing Burgers!               0.80
# 9070                                   Best fries EVER.               1.20
#
# [9071 rows x 2 columns]

# %%
import pandas as pd

file_name = list(uploaded.keys())[0]

# Read the Excel file into a DataFrame
df = pd.read_excel(file_name)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                                 text
# 0  Some of the best food I've ever had! We were r...
# 1  Loved it the food was great. Can’t wait to go ...
# 2  Amazing food and staff was great! Can’t wait t...
# 3  This place is the sleeper hit of Wise County. ...
# 4                                 Food was wonderful

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# !pip install pandas spacy sentence-transformers
import pandas as pd
import spacy
from nltk.tokenize import word_tokenize
from nltk.metrics import jaccard_distance
from nltk.corpus import wordnet
from sentence_transformers import SentenceTransformer, util

nlp = spacy.load("en_core_web_sm")
df = pd.read_excel('PunctuationLast.xlsx')

# Lexical Consistency
def lexical_consistency(text1, text2):
    words1 = set(word_tokenize(str(text1)))
    words2 = set(word_tokenize(str(text2)))
    jaccard_sim = 1 - jaccard_distance(words1, words2)
    return jaccard_sim

df['Lexical_Consistency'] = df['text'].apply(lambda text: lexical_consistency(text, text))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.6 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=432192c34a88508d275fc6eaa82c900dfc932ada0527bcd2e239c6c56c72e449
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...
